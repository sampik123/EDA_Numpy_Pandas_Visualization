# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\user\\Downloads\\Python Problems\\Numpy,Pandas &Visualizaation\\Files_Dataset\\data_#na.csv")

# %%
df
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %%
#using the pandas creating a dataset
pd.DataFrame({'Name':['Priyang', 'Aadhya'], 'Marks':['98.0', np.nan]})
# Out:
#       Name Marks
# 0  Priyang  98.0
# 1   Aadhya   NaN

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     2
# Grades    2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   5 non-null      float64
#  2   Grades  5 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %%
df.describe().T
# Out:
#        count  mean       std   min   25%   50%   75%   max
# Marks    5.0  91.2  7.259477  82.0  87.0  90.0  98.0  99.0

# %%
df[df['Marks'] == 0]
# Out:
# Empty DataFrame
# Columns: [Name, Marks, Grades]
# Index: []

# %%
df['Marks'].value_counts()
# Out:
# 98.0    1
# 99.0    1
# 87.0    1
# 90.0    1
# 82.0    1
# Name: Marks, dtype: int64

# %%
df.groupby('Name')['Marks'].sum().reset_index()
# Out:
#       Name  Marks
# 0   Aadhya    0.0
# 1  Archana   82.0
# 2   Krisha   99.0
# 3   Mittal    0.0
# 4   Parshv   90.0
# 5  Priyang   98.0
# 6   Vedant   87.0

# %%
df
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %%
df.isnull().sum().sum()
# Out:
# 4

# %%
mask = df['Marks'].isnull()
df[mask]
# Out:
#      Name  Marks Grades
# 1  Aadhya    NaN     AB
# 5  Mittal    NaN     BA

# %%
df[df['Marks'].isnull()]
# Out:
#      Name  Marks Grades
# 1  Aadhya    NaN     AB
# 5  Mittal    NaN     BA

# %%
df[df['Marks'].notnull()]
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 6  Archana   82.0     BB

# %%
df[df['Marks'].isin([98,99,82])]
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 2   Krisha   99.0     AA
# 6  Archana   82.0     BB

# %%
mask = df['Marks'].isin([98,99,82])
df[mask]
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 2   Krisha   99.0     AA
# 6  Archana   82.0     BB

# %%
df
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %%
df.fillna(0)
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0      0
# 1   Aadhya    0.0     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0      0
# 4   Parshv   90.0     AC
# 5   Mittal    0.0     BA
# 6  Archana   82.0     BB

# %%
df['Marks'].fillna(df['Marks'].mean(),inplace = True)

# %%
df
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya   91.2     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal   91.2     BA
# 6  Archana   82.0     BB

# %%
df['Grades'] = df['Grades'].fillna(df['Grades'].mode())

# %%
df
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0     AA
# 1   Aadhya   91.2     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0     BA
# 4   Parshv   90.0     AC
# 5   Mittal   91.2     BA
# 6  Archana   82.0     BB

# %%
df.select_dtypes(include='object')
# Out:
#       Name Grades
# 0  Priyang     AA
# 1   Aadhya     AB
# 2   Krisha     AA
# 3   Vedant     BA
# 4   Parshv     AC
# 5   Mittal     BA
# 6  Archana     BB

# %%
df.select_dtypes(include = ['object', 'category', 'integer', 'float'])
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0     AA
# 1   Aadhya   91.2     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0     BA
# 4   Parshv   90.0     AC
# 5   Mittal   91.2     BA
# 6  Archana   82.0     BB

# %% [markdown]
# -- na_values
# df2 = pd.read_csv('ahdf\adjfl\dll.csv', na_values = ['not available', 'wrong data', etc etc])
#
# if we want to treat some strings and NaN while loading the dataset then we can mention this.

# %%
df2 = df = pd.read_csv("C:\\Users\\user\\Downloads\\Python Problems\\Numpy,Pandas &Visualizaation\\Files_Dataset\\data_#na.csv")

# %%
df2
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %%
df2.dropna()
# Out:
#       Name  Marks Grades
# 2   Krisha   99.0     AA
# 4   Parshv   90.0     AC
# 6  Archana   82.0     BB

# %%
df2['Marks'] = df2['Marks'].dropna()
df2
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %%
df.groupby('Grades')['Name'].count().reset_index(name='Count of Name')
# Out:
#   Grades  Count of Name
# 0     AA              1
# 1     AB              1
# 2     AC              1
# 3     BA              1
# 4     BB              1
