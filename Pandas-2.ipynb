# %%
import pandas as pd

# %%
df = pd.read_csv("D:/Full Stack Data Science/pandas/TR School Registry.csv")

# %%
df
# Out:
#        School_Code                                   School_Name Is_Active?  \
# 0     M16010100108  DAKSHIN LANKAMURA J.B SCHOOL (MORNING SHIFT)        Yes
# 1     N16010100109            LANKAMURA H.S. SCHOOL (NOON SHIFT)        Yes
# 2     M16010100109         LANKAMURA H.S. SCHOOL (MORNING SHIFT)        Yes
# 3     M16010100110  DAKSHIN NARAYANPUR SB SCHOOL (MORNING SHIFT)        Yes
# 4     N16010100207            MADHYA BHUBANBAN HIGH (NOON SHIFT)        Yes
# ...            ...                                           ...        ...
# 5819  N16080801001  JOYPUR (NABINCHERRA).SR.B.SCHOL (Noon Shift)         No
# 5820  N16080801301      DHANICHERRA  SR. B. SCHOOL. (Noon Shift)         No
# 5821  N16080801303   KINACHARAN T/PARA SR.B.SCHOOL. (Noon Shift)         No
# 5822  N16080900105   KALIPUR (JITU DIGIR PAR) JR.B. (Noon Shift)         No
# 5823  M16080900110       GOBINDAPUR SR.B.SCHOOL. (Morning Shift)         No
#
# ...

# %%
df.head()
# Out:
#     School_Code                                   School_Name Is_Active?  \
# 0  M16010100108  DAKSHIN LANKAMURA J.B SCHOOL (MORNING SHIFT)        Yes
# 1  N16010100109            LANKAMURA H.S. SCHOOL (NOON SHIFT)        Yes
# 2  M16010100109         LANKAMURA H.S. SCHOOL (MORNING SHIFT)        Yes
# 3  M16010100110  DAKSHIN NARAYANPUR SB SCHOOL (MORNING SHIFT)        Yes
# 4  N16010100207            MADHYA BHUBANBAN HIGH (NOON SHIFT)        Yes
#
#   Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 0       12-07-2024             14-08-2024             1              5
# 1       12-07-2024             14-08-2024             1             12
# 2       12-07-2024             14-08-2024             1             12
# 3       12-07-2024             14-08-2024             1              8
# 4       12-07-2024             14-08-2024             1             10
#
#    District_Name                        Block_Name  \
# ...

# %%
df.head(5)
# Out:
#     School_Code                                   School_Name Is_Active?  \
# 0  M16010100108  DAKSHIN LANKAMURA J.B SCHOOL (MORNING SHIFT)        Yes
# 1  N16010100109            LANKAMURA H.S. SCHOOL (NOON SHIFT)        Yes
# 2  M16010100109         LANKAMURA H.S. SCHOOL (MORNING SHIFT)        Yes
# 3  M16010100110  DAKSHIN NARAYANPUR SB SCHOOL (MORNING SHIFT)        Yes
# 4  N16010100207            MADHYA BHUBANBAN HIGH (NOON SHIFT)        Yes
#
#   Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 0       12-07-2024             14-08-2024             1              5
# 1       12-07-2024             14-08-2024             1             12
# 2       12-07-2024             14-08-2024             1             12
# 3       12-07-2024             14-08-2024             1              8
# 4       12-07-2024             14-08-2024             1             10
#
#    District_Name                        Block_Name  \
# ...

# %%
print(df.head(5))
# Out:
#     School_Code                                   School_Name Is_Active?  \
# 0  M16010100108  DAKSHIN LANKAMURA J.B SCHOOL (MORNING SHIFT)        Yes
# 1  N16010100109            LANKAMURA H.S. SCHOOL (NOON SHIFT)        Yes
# 2  M16010100109         LANKAMURA H.S. SCHOOL (MORNING SHIFT)        Yes
# 3  M16010100110  DAKSHIN NARAYANPUR SB SCHOOL (MORNING SHIFT)        Yes
# 4  N16010100207            MADHYA BHUBANBAN HIGH (NOON SHIFT)        Yes
#
#   Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 0       12-07-2024             14-08-2024             1              5
# 1       12-07-2024             14-08-2024             1             12
# 2       12-07-2024             14-08-2024             1             12
# 3       12-07-2024             14-08-2024             1              8
# 4       12-07-2024             14-08-2024             1             10
#
#    District_Name                        Block_Name  \
# ...

# %%
df.tail()
# Out:
#        School_Code                                   School_Name Is_Active?  \
# 5819  N16080801001  JOYPUR (NABINCHERRA).SR.B.SCHOL (Noon Shift)         No
# 5820  N16080801301      DHANICHERRA  SR. B. SCHOOL. (Noon Shift)         No
# 5821  N16080801303   KINACHARAN T/PARA SR.B.SCHOOL. (Noon Shift)         No
# 5822  N16080900105   KALIPUR (JITU DIGIR PAR) JR.B. (Noon Shift)         No
# 5823  M16080900110       GOBINDAPUR SR.B.SCHOOL. (Morning Shift)         No
#
#      Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 5819        17-4-2024             14-08-2024             1              8
# 5820        17-4-2024             14-08-2024             1              8
# 5821        17-4-2024             14-08-2024             1              8
# 5822        17-4-2024             14-08-2024             1              5
# 5823        17-4-2024             14-08-2024             1              8
#
# ...

# %%
df.tail(8)
# Out:
#        School_Code                                   School_Name Is_Active?  \
# 5816  N16080800501      KARAICHERRA  SR. B. SCHOOL. (Noon Shift)         No
# 5817  N16080800801       GADACHERRA  SR. B. SCHOOL. (Noon Shift)         No
# 5818  N16080800802    LAXMIPUR  (PTL)  SR.B.SCHOOL. (Noon Shift)         No
# 5819  N16080801001  JOYPUR (NABINCHERRA).SR.B.SCHOL (Noon Shift)         No
# 5820  N16080801301      DHANICHERRA  SR. B. SCHOOL. (Noon Shift)         No
# 5821  N16080801303   KINACHARAN T/PARA SR.B.SCHOOL. (Noon Shift)         No
# 5822  N16080900105   KALIPUR (JITU DIGIR PAR) JR.B. (Noon Shift)         No
# 5823  M16080900110       GOBINDAPUR SR.B.SCHOOL. (Morning Shift)         No
#
#      Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 5816        17-4-2024             14-08-2024             1              8
# 5817        17-4-2024             14-08-2024             1              8
# ...

# %%
df.sample(5)
# Out:
#        School_Code                                 School_Name Is_Active?  \
# 1506  M16030102901       NAILAHABARI SB SCHOOL (MORNING SHIFT)        Yes
# 2662  M16040600104  BHAGYAPUR I.M. HIGH SCHOOL (MORNING SHIFT)        Yes
# 3570  M16061200807   RAMSARDAR PARA J.B SCHOOL (MORNING SHIFT)        Yes
# 4431  M16070402204      RANGA CHARA J.B SCHOOL (MORNING SHIFT)        Yes
# 2790  N16040800403         KRISHNAPUR H.S.SCHOOL. (NOON SHIFT)        Yes
#
#      Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 1506       12-07-2024             14-08-2024             1              8
# 2662       12-07-2024             14-08-2024             1             10
# 3570       12-07-2024             14-08-2024             1              5
# 4431       12-07-2024             14-08-2024             1              5
# 2790       12-07-2024             14-08-2024             1             12
#
# ...

# %%
df.describe()
# Out:
#        Lowest_Class  Highest_Class  District_ID       Block_ID     Latitude  \
# count   5824.000000    5824.000000  5824.000000    5824.000000  5824.000000
# mean       0.836538       7.662431  1604.131525  160420.338255    23.771687
# std        1.060135       2.557071     2.151135     214.607432     0.842373
# min       -3.000000       5.000000  1601.000000  160101.000000     0.000000
# 25%        1.000000       5.000000  1602.000000  160214.000000    23.532930
# 50%        1.000000       8.000000  1604.000000  160404.000000    23.840405
# 75%        1.000000      10.000000  1606.000000  160615.000000    24.058187
# max        6.000000      12.000000  1608.000000  160810.000000    24.546551
#
#          Longitude  State_ID  Village_ID  School_Category_ID  \
# count  5824.000000    5824.0      5824.0         5824.000000
# mean     91.606271      16.0         0.0            2.458791
# std       2.958655       0.0         0.0            1.813004
# ...

# %%
df.dtypes
# Out:
# School_Code                 object
# School_Name                 object
# Is_Active?                  object
# Created_DateTime            object
# Last_Modified_DateTime      object
# Lowest_Class                 int64
# Highest_Class                int64
# District_Name               object
# Block_Name                  object
# School_Category             object
# School_Management           object
# District_ID                  int64
# Block_ID                     int64
# Latitude                   float64
# Longitude                  float64
# Cluster_Name                object
# Cluster_ID                  object
# State_Name                  object
# State_ID                     int64
# Medium                      object
# Village_Name                object
# Village_ID                   int64
# School_Category_ID           int64
# School_Established_Year      int64
# School_Management_ID         int64
# Affiliation_Board           object
# Contact_Name                object
# ...

# %%
def add_one(x):
    return x + 1

df['School_Management_ID'] = df['School_Management_ID'].apply(add_one)


df.head(5)
# Out:
#     School_Code                                   School_Name Is_Active?  \
# 0  M16010100108  DAKSHIN LANKAMURA J.B SCHOOL (MORNING SHIFT)        Yes
# 1  N16010100109            LANKAMURA H.S. SCHOOL (NOON SHIFT)        Yes
# 2  M16010100109         LANKAMURA H.S. SCHOOL (MORNING SHIFT)        Yes
# 3  M16010100110  DAKSHIN NARAYANPUR SB SCHOOL (MORNING SHIFT)        Yes
# 4  N16010100207            MADHYA BHUBANBAN HIGH (NOON SHIFT)        Yes
#
#   Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 0       12-07-2024             14-08-2024             1              5
# 1       12-07-2024             14-08-2024             1             12
# 2       12-07-2024             14-08-2024             1             12
# 3       12-07-2024             14-08-2024             1              8
# 4       12-07-2024             14-08-2024             1             10
#
#    District_Name                        Block_Name  \
# ...

# %%
df['new_column'] = df['School_Management_ID'] + df['School_Type_ID']

# %%
df.head()
# Out:
#     School_Code                                   School_Name Is_Active?  \
# 0  M16010100108  DAKSHIN LANKAMURA J.B SCHOOL (MORNING SHIFT)        Yes
# 1  N16010100109            LANKAMURA H.S. SCHOOL (NOON SHIFT)        Yes
# 2  M16010100109         LANKAMURA H.S. SCHOOL (MORNING SHIFT)        Yes
# 3  M16010100110  DAKSHIN NARAYANPUR SB SCHOOL (MORNING SHIFT)        Yes
# 4  N16010100207            MADHYA BHUBANBAN HIGH (NOON SHIFT)        Yes
#
#   Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 0       12-07-2024             14-08-2024             1              5
# 1       12-07-2024             14-08-2024             1             12
# 2       12-07-2024             14-08-2024             1             12
# 3       12-07-2024             14-08-2024             1              8
# 4       12-07-2024             14-08-2024             1             10
#
#    District_Name                        Block_Name  \
# ...

# %%
filtered_data = df[df['Lowest_Class'] > 5]

filtered_data
# Out:
#        School_Code                                        School_Name  \
# 69    N16010101608           BANI VIDYA PITH GIRLS' H./S (NOON SHIFT)
# 101   N16010102414  SWAMI DAYALANANDA VIDYANIKETAN CLASS - XII SCH...
# 137   N16010104504      BIDROHI KABI NAZRUL VIDYA BHAVAN (NOON SHIFT)
# 189   N16010300204           ISHAN CHANDRA NAGAR (P) H.S (NOON SHIFT)
# 294   N16010800501                KALAGACHIA HIGH SCHOOL (NOON SHIFT)
# ...            ...                                                ...
# 5721  N16061701808     EKALAVYA MODEL RESIDENTIAL SCHOOL (Noon Shift)
# 5748  M16070103206              CHANDRAPUR H.S SCHOOL (Morning Shift)
# 5752  M16070200311               JALEMABARI HS SCHOOL (Morning Shift)
# 5786  M16070501604               AMPINAGAR H.S SCHOOL (Morning Shift)
# 5800  M16070800302         TRIPURA SUNDARI H.S SCHOOL (Morning Shift)
#
#      Is_Active? Created_DateTime Last_Modified_DateTime  Lowest_Class  \
# ...

# %%
filtered_data2 = df[(df['Lowest_Class'] > 2) & (df['Highest_Class'] < 10)]

filtered_data2
# Out:
#        School_Code                                        School_Name  \
# 1505  M16030102714  EKALAVYA MODEL RESIDENTIAL SCHOOL (MORNING SHIFT)
# 2318  M16030901103  RADHARAMAN MEMORIAL ASHRAM JB SCHOOL (MORNING ...
# 4609  M16070601806                      ASHRAM SCHOOL (MORNING SHIFT)
#
#      Is_Active? Created_DateTime Last_Modified_DateTime  Lowest_Class  \
# 1505        Yes       12-07-2024             14-08-2024             6
# 2318        Yes       12-07-2024             14-08-2024             3
# 4609        Yes       12-07-2024             14-08-2024             3
#
#       Highest_Class District_Name    Block_Name      School_Category  ...  \
# 1505              8       DHALAI       AMBASSA    Upper Primary only  ...
# 2318              5       DHALAI   AMBASSA M.C               Primary  ...
# 4609              5       GOMATI       KARBOOK               Primary  ...
#
#      Affiliation_Board     Contact_Name  Contact_Number             Email_ID  \
# ...

# %%
filtered_data3 = df[ (df['Highest_Class'] < 12) & (df['Lowest_Class'] > 1) & (df['Is_Active?'] == 'Yes')]

filtered_data3
# Out:
#        School_Code                                        School_Name  \
# 294   N16010800501                KALAGACHIA HIGH SCHOOL (NOON SHIFT)
# 1115  N16021002414                    RESIDENTIAL SCHOOL (NOON SHIFT)
# 1505  M16030102714  EKALAVYA MODEL RESIDENTIAL SCHOOL (MORNING SHIFT)
# 2318  M16030901103  RADHARAMAN MEMORIAL ASHRAM JB SCHOOL (MORNING ...
# 3794  N16061500803            UTTAR RAMCHANDRA GHAT HIGH (NOON SHIFT)
# 4235  N16070200912     EKLAVYA MODEL  RESIDENTIAL SCHOOL (NOON SHIFT)
# 4609  M16070601806                      ASHRAM SCHOOL (MORNING SHIFT)
#
#      Is_Active? Created_DateTime Last_Modified_DateTime  Lowest_Class  \
# 294         Yes       12-07-2024             14-08-2024             6
# 1115        Yes       12-07-2024             14-08-2024             6
# 1505        Yes       12-07-2024             14-08-2024             6
# 2318        Yes       12-07-2024             14-08-2024             3
# ...

# %%
df.isnull().sum()
# Out:
# School_Code                   0
# School_Name                   0
# Is_Active?                    0
# Created_DateTime              0
# Last_Modified_DateTime        0
# Lowest_Class                  0
# Highest_Class                 0
# District_Name                 0
# Block_Name                    0
# School_Category               0
# School_Management             0
# District_ID                   0
# Block_ID                      0
# Latitude                      0
# Longitude                     0
# Cluster_Name                  0
# Cluster_ID                    0
# State_Name                    0
# State_ID                      0
# Medium                        0
# Village_Name                526
# Village_ID                    0
# School_Category_ID            0
# School_Established_Year       0
# School_Management_ID          0
# Affiliation_Board          4001
# Contact_Name                  3
# Contact_Number                2
# Email_ID                   3180
# ...

# %%
df['Village_Name'] = df['Village_Name'].fillna('Na')

df.isnull().sum()
# Out:
# School_Code                   0
# School_Name                   0
# Is_Active?                    0
# Created_DateTime              0
# Last_Modified_DateTime        0
# Lowest_Class                  0
# Highest_Class                 0
# District_Name                 0
# Block_Name                    0
# School_Category               0
# School_Management             0
# District_ID                   0
# Block_ID                      0
# Latitude                      0
# Longitude                     0
# Cluster_Name                  0
# Cluster_ID                    0
# State_Name                    0
# State_ID                      0
# Medium                        0
# Village_Name                  0
# Village_ID                    0
# School_Category_ID            0
# School_Established_Year       0
# School_Management_ID          0
# Affiliation_Board          4001
# Contact_Name                  3
# Contact_Number                2
# Email_ID                   3180
# ...

# %%
df = df.dropna(subset = ['Affiliation_Board'])

df.isnull().sum()
# Out:
# School_Code                   0
# School_Name                   0
# Is_Active?                    0
# Created_DateTime              0
# Last_Modified_DateTime        0
# Lowest_Class                  0
# Highest_Class                 0
# District_Name                 0
# Block_Name                    0
# School_Category               0
# School_Management             0
# District_ID                   0
# Block_ID                      0
# Latitude                      0
# Longitude                     0
# Cluster_Name                  0
# Cluster_ID                    0
# State_Name                    0
# State_ID                      0
# Medium                        0
# Village_Name                  0
# Village_ID                    0
# School_Category_ID            0
# School_Established_Year       0
# School_Management_ID          0
# Affiliation_Board             0
# Contact_Name                  0
# Contact_Number                0
# Email_ID                    371
# ...

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# School_Code                0
# School_Name                0
# Is_Active?                 0
# Created_DateTime           0
# Last_Modified_DateTime     0
# Lowest_Class               0
# Highest_Class              0
# District_Name              0
# Block_Name                 0
# School_Category            0
# School_Management          0
# District_ID                0
# Block_ID                   0
# Latitude                   0
# Longitude                  0
# Cluster_Name               0
# Cluster_ID                 0
# State_Name                 0
# State_ID                   0
# Medium                     0
# Village_Name               0
# Village_ID                 0
# School_Category_ID         0
# School_Established_Year    0
# School_Management_ID       0
# Affiliation_Board          0
# Contact_Name               0
# Contact_Number             0
# Is_Minority_School?        0
# School_Location            0
# School_Type_ID             0
# School_Type                0
# ...

# %%
df = df.rename(columns = {'School_Code' : 'School_ID'})
df.head()
# Out:
#       School_ID                                     School_Name Is_Active?  \
# 1  N16010100109              LANKAMURA H.S. SCHOOL (NOON SHIFT)        Yes
# 2  M16010100109           LANKAMURA H.S. SCHOOL (MORNING SHIFT)        Yes
# 4  N16010100207              MADHYA BHUBANBAN HIGH (NOON SHIFT)        Yes
# 5  M16010100207           MADHYA BHUBANBAN HIGH (MORNING SHIFT)        Yes
# 6  N16010100209  PASCHIM BHUBANBAN ENG.MED. SCHOOL (NOON SHIFT)        Yes
#
#   Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 1       12-07-2024             14-08-2024             1             12
# 2       12-07-2024             14-08-2024             1             12
# 4       12-07-2024             14-08-2024             1             10
# 5       12-07-2024             14-08-2024             1             10
# 6       12-07-2024             14-08-2024             1             10
#
#    District_Name                        Block_Name  \
# ...

# %%
df = df.drop(columns= ['Affiliation_Board'])

df.head()
# Out:
#       School_ID                                     School_Name Is_Active?  \
# 1  N16010100109              LANKAMURA H.S. SCHOOL (NOON SHIFT)        Yes
# 2  M16010100109           LANKAMURA H.S. SCHOOL (MORNING SHIFT)        Yes
# 4  N16010100207              MADHYA BHUBANBAN HIGH (NOON SHIFT)        Yes
# 5  M16010100207           MADHYA BHUBANBAN HIGH (MORNING SHIFT)        Yes
# 6  N16010100209  PASCHIM BHUBANBAN ENG.MED. SCHOOL (NOON SHIFT)        Yes
#
#   Created_DateTime Last_Modified_DateTime  Lowest_Class  Highest_Class  \
# 1       12-07-2024             14-08-2024             1             12
# 2       12-07-2024             14-08-2024             1             12
# 4       12-07-2024             14-08-2024             1             10
# 5       12-07-2024             14-08-2024             1             10
# 6       12-07-2024             14-08-2024             1             10
#
#    District_Name                        Block_Name  \
# ...
